# %% [markdown]
# <h1 align="center">Changes in sentinel measures of primary care activity during the pandemic</h1>
#
# The purpose of this notebook is to provide measures of overall activity at the practice level during the pandemic.
#
# The following sentinel measures are provided:
# * [Sentinel Measure 1](#sentinel-measure-1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ebmdatalab import charts
from IPython.display import HTML
# %matplotlib inline

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# <a id="sentinel-measure-1"></a>
# ### Sentinel Measure 1

# %%
data_sentinel_measure_1 = pd.read_csv('../output/measure_sentinel_measure_x.csv')

def convert_datetime(df):
    df['date'] = pd.to_datetime(df['date'])
    
convert_datetime(data_sentinel_measure_1)

charts.deciles_chart(
    data_sentinel_measure_1,
    period_column="date",
    column="value",
    title="Sentinel Measure 1",
    ylabel="rate per 1000",
    show_outer_percentiles=False,
    show_legend=True,
);
