# %% [markdown]
# <h1 align="center">Changes in sentinel measures of primary care activity during the pandemic</h1>
#
# The purpose of this notebook is to provide measures of overall activity at the practice level during the pandemic.
#
# The following sentinel measures are provided:
# * [2469: O/E - Systolic BP reading](#systolic_bp)
# * [QRISK2 cardiovascular disease 10 risk score](#qrisk2)
# * [Serum Cholesterol level](#cholesterol)
# * [Serum Bilirubin level](#bilirubin)
# * [Serum TSH level](#serum_tsh)
# * [Red blood cell count](#rbc_fbc)
# * [Haemoglobin A1c level - IFCC standardised](#hba1c)
# * [Serum Sodium level](#serum_sodium)
# * [Asthma annual review](#asthma)
# * [Chronic obstrutive pulmonary disease annual review](#copd)

# %%
from IPython.display import HTML
import pandas as pd
import matplotlib.pyplot as plt
from utilities import *

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
sentinel_measures = ["qrisk2", "asthma", "copd"]

data_dict = {}

for measure in sentinel_measures:
    df = load_and_drop(measure)
    data_dict[measure] = df
    
data_dict_practice = {}

for measure in sentinel_measures:
    df = load_and_drop(measure, practice=True)
    data_dict_practice[measure] = df

sentinel_measure_codelist_mapping_dict = {"systolic_bp":"opensafely-chronic-respiratory-disease", "qrisk2":"user-richard-croker-cvd-risk-assessment-score-qof", "serum_cholesterol": "opensafely-chronic-respiratory-disease", "serum_bilirubin": "opensafely-chronic-respiratory-disease", "serum_tsh": "opensafely-chronic-respiratory-disease", "rbc": "opensafely-chronic-respiratory-disease", "hba1c": "opensafely-chronic-respiratory-disease", "serum_sodium": "opensafely-chronic-respiratory-disease", "asthma": "user-richard-croker-asthma-annual-review-qof", "copd": "user-richard-croker-chronic-obstructive-pulmonary-disease-copd-review-qof"}

codelist_dict = {}
for measure in sentinel_measures:
    codelist_name = sentinel_measure_codelist_mapping_dict[measure]
    codelist = pd.read_csv(f'../codelists/{codelist_name}.csv')
    codelist_dict[measure] = codelist

# %% [markdown]
# <a id="systolic_bp"></a>
# ### O/E - Systolic BP
#
# Description:

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'systolic_bp', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="qrisk"></a>
# ### QRISK2 Cardiovascular Disease 10 year risk score

# %%
generate_sentinel_measure(data_dict=data_dict, data_dict_practice=data_dict_practice, codelist_dict=codelist_dict, measure='qrisk2', code_column='code', term_column='term', dates_list=["2020-02-01", "2020-04-01", "2020-12-01"], interactive=False)
# Out:
# Practices included: 39 (121.88%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 494.4 (IDR: 552.7), April Median: 521.7 (IDR: 564.3), Dec Median: 500.0 (IDR: 800.0)
# Change in median from Feb 2020: April: 5.52%; December: 1.12%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4.507590e+08</th>
#       <td>4.507590e+08</td>
#       <td>243.0</td>
#       <td>0.243</td>
#       <td>Framingham coronary heart disease 10 year risk score</td>
#     </tr>
#     <tr>
#       <th>7.180870e+08</th>
#       <td>7.180870e+08</td>
#       <td>253.0</td>
#       <td>0.253</td>
#       <td>QRISK2 cardiovascular disease 10 year risk score</td>
#     </tr>
#     <tr>
#       <th>1.085871e+15</th>
#       <td>1.085871e+15</td>
#       <td>815.0</td>
#       <td>0.815</td>
#       <td>QRISK3 cardiovascular disease 10 year risk calculator score</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="cholesterol"></a>
# ### Serum Cholesterol Level

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_cholesterol', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="bilirubin"></a>
# ### Serum Bilirubin Level

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_bilirubin', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="serum_tsh"></a>
# ### Serum TSH Level

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_tsh', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="rbc_fbc"></a>
# ### Red Blood Cell Count

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'rbc', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="hba1c"></a>
# ### Haemoglobin A1c Level - IFCC Standardised

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'hba1c', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="serum_sodium"></a>
# ### Serum Sodium Level

# %%
# generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_sodium', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])

# %% [markdown]
# <a id="asthma"></a>
# ### Asthma Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'asthma', 'code', 'term', ["2020-02-01", "2020-04-01", "2020-12-01"], interactive=False)
# Out:
# Practices included: 40 (125.0%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 571.3), April Median: 500.0 (IDR: 692.3), Dec Median: 502.0 (IDR: 760.0)
# Change in median from Feb 2020: April: 0.00%; December: 0.40%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>390877003.0</th>
#       <td>390877003.0</td>
#       <td>246.0</td>
#       <td>0.246</td>
#       <td>Step up change in asthma management plan</td>
#     </tr>
#     <tr>
#       <th>390872009.0</th>
#       <td>390872009.0</td>
#       <td>282.0</td>
#       <td>0.282</td>
#       <td>Change in asthma management plan</td>
#     </tr>
#     <tr>
#       <th>270442000.0</th>
#       <td>270442000.0</td>
#       <td>792.0</td>
#       <td>0.792</td>
#       <td>Asthma monitoring check done</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="copd"></a>
# ### Chronic Obstructive Pulmonary Disease Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'copd', 'code', 'term', ["2020-02-01", "2020-04-01", "2020-12-01"], interactive=False)
# Out:
# Practices included: 38 (118.75%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 498.0 (IDR: 416.7), April Median: 500.0 (IDR: 620.7), Dec Median: 500.0 (IDR: 635.7)
# Change in median from Feb 2020: April: 0.40%; December: 0.40%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7.606210e+14</th>
#       <td>7.606210e+14</td>
#       <td>242.0</td>
#       <td>0.242</td>
#       <td>Chronic obstructive pulmonary disease 6 monthly review</td>
#     </tr>
#     <tr>
#       <th>7.606010e+14</th>
#       <td>7.606010e+14</td>
#       <td>247.0</td>
#       <td>0.247</td>
#       <td>Chronic obstructive pulmonary disease 3 monthly review</td>
#     </tr>
#     <tr>
#       <th>3.947030e+08</th>
#       <td>3.947030e+08</td>
#       <td>803.0</td>
#       <td>0.803</td>
#       <td>Chronic obstructive pulmonary disease annual review</td>
#     </tr>
#   </tbody>
# </table>
