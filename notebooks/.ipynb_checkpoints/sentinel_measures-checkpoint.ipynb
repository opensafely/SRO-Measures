# %% [markdown]
# <h1 align="center">Changes in sentinel measures of primary care activity during the pandemic</h1>
#
# The purpose of this notebook is to provide measures of overall activity at the practice level during the pandemic.
#
# The following sentinel measures are provided:
# * [2469: O/E - Systolic BP reading](#systolic_bp)
# * ["XaQVY" - QRISK2 cardiovascular disease 10 risk score](#qrisk2)
# * ["XE2eD" - Serum Cholesterol level](#cholesterol)
# * ["44E" - Serum Bilirubin level](#bilirubin)
# * ["XaELV" - Serum TSH level](#serum_tsh)
# * ["426" - Red blood cell count](#rbc_fbc)
# * ["XaPbt" - Haemoglobin A1c level - IFCC standardised](#hba1c)
# * ["XE2q0" - Serum Sodium level](#serum_sodium)
# * ["Xaleq" - Asthma annual review](#asthma)
# * ["Xalet" - Chronic obstrutive pulmonary disease annual review](#copd)

# %%
from IPython.display import HTML
import pandas as pd
import matplotlib.pyplot as plt
from utilities import *

# %matplotlib inline

# %%
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
sentinel_measures = ["systolic_bp", "qrisk2", "serum_cholesterol", "serum_bilirubin", "serum_tsh", "rbc", "hba1c", "serum_sodium", "asthma", "copd"]

data_dict = {}

for measure in sentinel_measures:
    df = load_and_drop(measure)
    data_dict[measure] = df
    
data_dict_practice = {}

for measure in sentinel_measures:
    df = load_and_drop(measure, practice=True)
    data_dict_practice[measure] = df

sentinel_measure_codelist_mapping_dict = {"systolic_bp":"opensafely-chronic-respiratory-disease", "qrisk2":"opensafely-chronic-respiratory-disease", "serum_cholesterol": "opensafely-chronic-respiratory-disease", "serum_bilirubin": "opensafely-chronic-respiratory-disease", "serum_tsh": "opensafely-chronic-respiratory-disease", "rbc": "opensafely-chronic-respiratory-disease", "hba1c": "opensafely-chronic-respiratory-disease", "serum_sodium": "opensafely-chronic-respiratory-disease", "asthma": "opensafely-chronic-respiratory-disease", "copd": "opensafely-chronic-respiratory-disease"}

codelist_dict = {}
for measure in sentinel_measures:
    codelist_name = sentinel_measure_codelist_mapping_dict[measure]
    codelist = pd.read_csv(f'../codelists/{codelist_name}.csv')
    codelist_dict[measure] = codelist

# %% [markdown]
# <a id="systolic_bp"></a>
# ### 2469: O/E - Systolic BP
#
# Description:

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'systolic_bp', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 304.2), April Median: 500.0 (IDR: 666.7), Dec Median: 506.0 (IDR: 505.5)
# Change in median from Feb 2020: April: 0.00%; December: 1.20%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>266.0</td>
#       <td>0.266</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>274.0</td>
#       <td>0.274</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>819.0</td>
#       <td>0.819</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>
# /Users/Louis/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <a id="qrisk"></a>
# ### "XaQVY" - QRISK2 Cardiovascular Disease 10 year risk score

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'qrisk2', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 315.6), April Median: 500.0 (IDR: 977.3), Dec Median: 466.6666666666667 (IDR: 442.9)
# Change in median from Feb 2020: April: 0.00%; December: -6.67%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>239.0</td>
#       <td>0.239</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>241.0</td>
#       <td>0.241</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>797.0</td>
#       <td>0.797</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="cholesterol"></a>
# ### "XE2eD" - Serum Cholesterol Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_cholesterol', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 322.6), April Median: 454.54545454545456 (IDR: 729.8), Dec Median: 500.0 (IDR: 403.6)
# Change in median from Feb 2020: April: -9.09%; December: 0.00%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>272.0</td>
#       <td>0.272</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>284.0</td>
#       <td>0.284</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>761.0</td>
#       <td>0.761</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="bilirubin"></a>
# ### "44E" - Serum Bilirubin Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_bilirubin', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 510.0 (IDR: 580.7), April Median: 449.53416149068323 (IDR: 696.7), Dec Median: 500.0 (IDR: 347.5)
# Change in median from Feb 2020: April: -11.86%; December: -1.96%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>248.0</td>
#       <td>0.248</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>818.0</td>
#       <td>0.818</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="serum_tsh"></a>
# ### "XaELV" - Serum TSH Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_tsh', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 451.4), April Median: 500.0 (IDR: 966.7), Dec Median: 500.0 (IDR: 484.8)
# Change in median from Feb 2020: April: 0.00%; December: 0.00%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>247.0</td>
#       <td>0.247</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>285.0</td>
#       <td>0.285</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>777.0</td>
#       <td>0.777</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="rbc_fbc"></a>
# ### "426" - Red Blood Cell Count

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'rbc', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 36 (124.14%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 244.8), April Median: 526.4945652173913 (IDR: 748.3), Dec Median: 458.3333333333333 (IDR: 444.0)
# Change in median from Feb 2020: April: 5.30%; December: -8.33%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>244.0</td>
#       <td>0.244</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>249.0</td>
#       <td>0.249</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>776.0</td>
#       <td>0.776</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="hba1c"></a>
# ### "XaPbt" - Haemoglobin A1c Level - IFCC Standardised

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'hba1c', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 484.375 (IDR: 729.5), April Median: 539.3939393939395 (IDR: 966.7), Dec Median: 500.0 (IDR: 444.8)
# Change in median from Feb 2020: April: 11.36%; December: 3.23%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>256.0</td>
#       <td>0.256</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>277.0</td>
#       <td>0.277</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>771.0</td>
#       <td>0.771</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="serum_sodium"></a>
# ### "XE2q0" - Serum Sodium Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_sodium', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 505.0), April Median: 500.0 (IDR: 784.9), Dec Median: 533.3333333333334 (IDR: 327.4)
# Change in median from Feb 2020: April: 0.00%; December: 6.67%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>232.0</td>
#       <td>0.232</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>272.0</td>
#       <td>0.272</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>762.0</td>
#       <td>0.762</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="asthma"></a>
# ### "Xaleq" - Asthma Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'asthma', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 397.7), April Median: 496.0 (IDR: 944.2), Dec Median: 508.77192982456137 (IDR: 297.1)
# Change in median from Feb 2020: April: -0.80%; December: 1.75%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>248.0</td>
#       <td>0.248</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>250.0</td>
#       <td>0.250</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>788.0</td>
#       <td>0.788</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="copd"></a>
# ### "Xalet" - Chronic Obstructive Pulmonary Disease Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'copd', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 0.01M (0.01M events)
# Feb Median: 500.0 (IDR: 414.3), April Median: 500.0 (IDR: 950.5), Dec Median: 502.0 (IDR: 467.9)
# Change in median from Feb 2020: April: 0.00%; December: 0.40%
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# /Users/Louis/Documents/DataLab/SRO-Measures/notebooks/utilities.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.sort_values('date', inplace=True)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>257.0</td>
#       <td>0.257</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>802.0</td>
#       <td>0.802</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>
