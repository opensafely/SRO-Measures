# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown

dbconn = os.environ.get('DBCONN', None)
if dbconn is None:
    display("No SQL credentials. Check that the file 'environ.txt' is present. Refer to readme for further information")
else:
    dbconn = dbconn.strip('"')

# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import plotting_all, closing_connection

# %% [markdown]
# ## Inspect Top-Level CTV3 Codes

# %%
sql = '''select 
LEFT(CTV3Code,1) AS first_digit,
'1' AS digits,
Description
from CTV3Dictionary
where RIGHT(CTV3Code,4)='....' 
and LEFT(CTV3Code,1) NOT IN (
'.', -- Read thesaurus
'0', -- occupations
'9') -- Administration
'''

pd.set_option('display.max_rows', 200)
with closing_connection(dbconn) as connection:
    codes = pd.read_sql(sql, connection)
codes
# Out:
#    first_digit digits                                        Description
# 0            1      1                                   History/symptoms
# 1            2      1       (Examination of patient) or (physical signs)
# 2            3      1                              Diagnostic procedures
# 3            4      1                              Laboratory procedures
# 4            5      1  (Radiol &/or physics in medicine) or (radiolog...
# 5            6      1                               Preventive procedure
# 6            7      1                   (Surgical operations) or (sites)
# 7            8      1                       Other therapeutic procedures
# 8            A      1                                 Infective disorder
# 9            B      1                           (Neoplasms) or (cancers)
# 10           C      1  Endocrine &/or [nutritional], [metabol] and [i...
# 11           D      1         Diseases of blood and blood-forming organs
# 12           E      1                             Mental health disorder
# 13           F      1      Nervous system/sense organ diseases (& (CNS)]
# 14           G      1       Cardiovascular system diseases (& [cardiac])
# 15           H      1                               Respiratory disorder
# 16           J      1            Gastrointestinal and digestive disorder
# 17           K      1                      Genitourinary system diseases
# 18           L      1  Complications of pregnancy, childbirth and the...
# 19           M      1                            Dermatological disorder
# 20           N      1    Musculoskeletal &/or connective tissue diseases
# 21           P      1                                Congenital disorder
# 22           Q      1    Conditions: [perinatal] or [fetal and neonatal]
# 23           R      1      [D]Symptoms, signs and ill-defined conditions
# 24           S      1                               Injury and poisoning
# 25           T      1                     Causes of injury and poisoning
# 26           U      1      [X]External causes of morbidity and mortality
# 27           Z      1                             Unspecified conditions
# 28           a      1                            Gastro-intestinal drugs
# 29           b      1                                Cardiovascular drug
# 30           c      1                                  Respiratory drugs
# 31           d      1                                           CNS drug
# 32           e      1                           Drugs used in infections
# 33           f      1                                    Endocrine drugs
# 34           g      1  Drugs used in obstetrics, gynaecology, and uri...
# 35           h      1  Drugs used in malignant disease and for immuno...
# 36           i      1                         Haematology/dietetic drugs
# 37           j      1      Drugs used in musculoskeletal/joint disorders
# 38           k      1                              Drugs used in the eye
# 39           l      1         Drugs used in the ear, nose and oropharynx
# 40           m      1                           Drugs acting on the skin
# 41           n      1                Immunological products and vaccines
# 42           o      1                                  Anaesthetic drugs
# 43           p      1                                          Appliance
# 44           q      1                             Incontinence appliance
# 45           r      1                       APPLIANCES & REAGENTS ETC(2)
# 46           s      1                                    Stoma appliance
# 47           u      1                                     Contrast media
# 48           y      1                        Drug release administration

# %% [markdown]
# ## Inspect Level 2 CTV3 Codes

# %%
digit = "1"

sql = f'''select 
LEFT(CTV3Code,2) AS first_digit,
'2' AS digits,
Description
from CTV3Dictionary
where RIGHT(CTV3Code,3)='...' 
AND RIGHT(CTV3Code,4)!='....' 
and CAST(LEFT(CTV3Code,1) AS VARCHAR) = '{digit}'
'''

pd.set_option('display.max_rows', 200)
with closing_connection(dbconn) as connection:
    codes = pd.read_sql(sql, connection)
codes
# Out:
#    first_digit digits                                  Description
# 0           11      2                             Depth of history
# 1           12      2                               Family history
# 2           13      2                  Social and personal history
# 3           14      2                         Past medical history
# 4           15      2      [Gynaecological] or [obstetric] history
# 5           16      2  [General] or [vague] or [multiple] symptoms
# 6           17      2                         Respiratory symptoms
# 7           18      2          Cardiovascular symptoms (& [heart])
# 8           19      2   Gastrointestinal symptoms (& [intestinal])
# 9           1A      2       Symptoms: [genitourinary] or [urinary]
# 10          1B      2            Nervous system symptoms (& [CNS])
# 11          1C      2           Ear &/or nose &/or throat symptoms
# 12          1D      2                  General symptom description
# 13          1E      2                         Rare history finding
# 14          1F      2                              Dietary history
# 15          1G      2                   Concerned about appearance
# 16          1H      2                       Awareness of diagnosis
# 17          1J      2                          Suspected condition
# 18          1Y      2      (Patient feels well) or (no complaints)
# 19          1Z      2                          History/symptom NOS
# 20          1z      2                     Read Code Administration

# %% [markdown]
# ## Create table of level 1 and level 2 CTV3 codes

# %%
digit = "2"

sql = f'''select 
LEFT(CTV3Code,CHARINDEX('.',CTV3Code)-1) AS first_digit,
CHARINDEX('.',CTV3Code)-1 AS digits,
Description
from CTV3Dictionary
where (RIGHT(CTV3Code,3)='...' OR RIGHT(CTV3Code,4)='....')
and LEFT(CTV3Code,1) NOT IN (
'.', -- Read thesaurus
'0', -- occupations
'1', -- History/symptoms
'9') -- Administration
'''

pd.set_option('display.max_rows', 200)
with closing_connection(dbconn) as connection:
    codes = pd.read_sql(sql, connection)
codes
# Out:
#     first_digit  digits                                        Description
# 0             2       1       (Examination of patient) or (physical signs)
# 1            21       2                               Depth of examination
# 2            22       2                     General examination of patient
# 3            23       2  (Examination of respirat system) or (O/E - che...
# 4            24       2  Examination of cardiovascular system (& [vascu...
# ..          ...     ...                                                ...
# 849           u       1                                     Contrast media
# 850          u1       2                               X-ray contrast media
# 851          u2       2          Magnetic resonance imaging contrast media
# 852          u3       2                          Ultrasound contrast media
# 853           y       1                        Drug release administration
#
# [854 rows x 3 columns]

# %% [markdown]
# ## Create table of level 2 & 3 CTV3 codes

# %%
digit = "4"

sql = f'''select 
LEFT(CTV3Code,CHARINDEX('.',CTV3Code)-1) AS first_digit,
CHARINDEX('.',CTV3Code)-1 AS digits,
Description
from CTV3Dictionary
where RIGHT(CTV3Code,2)='..' --(select codes like '123..')
and RIGHT(CTV3Code,4)!='....' --(don't select codes like '1....')
and LEFT(CTV3Code,1) NOT IN ('.') -- Read thesaurus
and LEFT(CTV3Code,1) = '{digit}'
'''

pd.set_option('display.max_rows', 400)
with closing_connection(dbconn) as connection:
    codes_l3 = pd.read_sql(sql, connection)

codes_l3
# Out:
#     first_digit  digits                                        Description
# 0            41       2  (Gen lab proc (& [invest][test])) or (result, ...
# 1           411       3                      Laboratory test not necessary
# 2           412       3                     Laboratory procedure performed
# 3           413       3                          Laboratory test requested
# 4           414       3                 Sample sent to laboratory for test
# 5           415       3                    Patient refused laboratory test
# 6           416       3               Laboratory test requested - not done
# 7           417       3  (Laboratory test result not back yet) or (awai...
# 8           418       3                            Lab. test result normal
# 9           419       3                    Laboratory test result abnormal
# 10          41A       3                        Lab. test result borderline
# 11          41B       3                                Laboratory test due
# 12          41C       3                     Patient informed - test result
# 13          41Z       3               Laboratory procedure - general - NOS
# 14           42       2                                        Haematology
# 15          421       3                              Haematology - general
# 16          422       3                           O/E: inspection of blood
# 17          423       3                   Haemoglobin estimation (& level)
# 18          424       3                                   Full blood count
# 19          425       3              (Haematocrit) or (packed cell volume)
# 20          426       3                               Red blood cell count
# 21          427       3                             Colour index (& level)
# 22          428       3                    Mean cell haemoglobin (& level)
# 23          429       3                Mean cell haemoglobin concentration
# 24          42A       3                                   Mean cell volume
# 25          42B       3                         Plasma viscosity (& level)
# 26          42C       3                                Red blood cell size
# 27          42D       3                               Red blood cell shape
# 28          42E       3                        RBC: [colour] or [staining]
# 29          42F       3                      RBC - red blood cell clumping
# 30          42G       3                             Red blood cell enzymes
# 31          42H       3               White blood cell count - observation
# 32          42I       3                Differential white blood cell count
# 33          42J       3                                   Neutrophil count
# 34          42K       3                     Eosinophil count - observation
# 35          42L       3                                     Basophil count
# 36          42M       3                                   Lymphocyte count
# 37          42N       3                       Monocyte count - observation
# 38          42O       3                         Immature white blood cells
# 39          42P       3                       Platelet count - observation
# 40          42Q       3                             Blood coagulation test
# 41          42R       3                     Serum iron: [tests] or [level]
# 42          42S       3                            Iron kinetics (& level)
# 43          42T       3                        Serum vitamin B12 (& level)
# 44          42U       3                             Blood folate (& level)
# 45          42V       3                   Haemoglobin variants (& [level])
# 46          42W       3  Hb. A1C - glycated haemoglobin (& [diabetic co...
# 47          42X       3                   Reticulocyte count - observation
# 48          42Y       3                             Other haematology test
# 49          42Z       3                  (Blood film) or (haematology NOS)
# 50          42a       3                        Plasma cell count (& level)
# 51          42b       3                    Percentage cell count (& level)
# 52          42c       3                            HbA1 - diabetic control
# 53           43       2                                         Immunology
# 54          431       3                            Blood grouping &/or ABO
# 55          432       3                              Rhesus blood grouping
# 56          433       3                                 Minor blood groups
# 57          434       3                               Blood cross-matching
# 58          435       3                        Transfusion centre ref. no.
# 59          436       3                              Rhesus antibody titre
# 60          437       3                  Coombs test - anti-human globulin
# 61          438       3  Syphilis infectious titre test (& [TPI][VDRL][...
# 62          439       3                             Rubella antibody titre
# 63          43A       3  Infectious mononucleosis test (& Paul Bunnell ...
# 64          43B       3  (Hep B test: (& [immun][SH-antigen]) or (Austr...
# 65          43C       3                  Human immunodeficiency virus test
# 66          43D       3                           Legionella antibody test
# 67          43E       3                              Infectious titres NOS
# 68          43F       3  Rheumatoid factor (& test: [latex] or [Rose Wa...
# 69          43G       3                                Autoantibody titres
# 70          43H       3                               L.E. cells (& level)
# 71          43I       3                                    Complement test
# 72          43J       3                        Immunoglobulins (& [level])
# 73          43K       3                              Immunoelectrophoresis
# 74          43L       3                                    Sample serology
# 75          43M       3                                   Hepatitis A test
# 76          43N       3                        Extractable nuclear antigen
# 77          43O       3                           DS DNA antibody by ELISA
# 78          43P       3           Non-rhesus red cell antibodies (& level)
# 79          43Z       3                                     Immunology NOS
# 80           44       2                                    Blood chemistry
# 81          441       3          General blood chemistry (& SMAC analysis)
# 82          442       3  (Thyr func test) or (level [TRH][TSH]) or (thy...
# 83          443       3         Gonadotrophin: [levels] or [serum studies]
# 84          444       3                  Feto/placental hormones (& level)
# 85          445       3                       Serum pregnancy test (B-HCG)
# 86          446       3              Female sex hormones - serum (& level)
# 87          447       3                Male sex hormones - serum (& level)
# 88          448       3  Pituitary &/or adrenal hormones (& level (& se...
# 89          449       3                Gastrointestinal hormones (& level)
# 90          44A       3                           Blood hormone levels NOS
# 91          44B       3                 Serum alpha-feto protein (& level)
# 92          44C       3    Enzymes &/or specific proteins (& misc - serum)
# 93          44D       3                 Liver function tests (& [general])
# 94          44E       3                              Serum bilirubin level
# 95          44F       3               Serum alkaline phosphatase (& level)
# 96          44G       3      Liver enzymes (& blood level [ALT] or [SGPT])
# 97          44H       3                       Cardiac enzymes (& [levels])
# 98          44I       3                       Serum electrolytes (& level)
# 99          44J       3  (Blood urea/ren funct) or (urea [& serum lev])...
# 100         44K       3                 (Blood urate) or (serum uric acid)
# 101         44L       3            Blood trace elements/vitamins (& level)
# 102         44M       3                              Serum/plasma proteins
# 103         44N       3      Serum protein electrophoresis (& [globulins])
# 104         44O       3                             Serum lipids (& level)
# 105         44P       3                        Serum cholesterol (& level)
# 106         44Q       3                      Serum triglycerides (& level)
# 107         44R       3                        Lipoprotein electrophoresis
# 108         44S       3      Serum amino-acids (& level (& phenylalanine))
# 109         44T       3                               Blood glucose method
# 110         44U       3         Blood sugar result: (& glucose (& plasma))
# 111         44V       3                Glucose tolerance (& blood (& test)
# 112         44W       3                                  Blood drug levels
# 113         44X       3    Blood: [toxic substance levels] or [toxicology]
# 114         44Y       3                                   Blood gas levels
# 115         44Z       3                                Blood chemistry NOS
# 116         44b       3                               Faecal fat screening
# 117         44c       3                           Serum lipoprotein levels
# 118         44d       3                          Plasma lipoprotein levels
# 119         44e       3                          Plasma triglyceride level
# 120         44f       3                                Serum glucose level
# 121          45       2                            Chemical function tests
# 122         451       3                               Renal function tests
# 123         452       3                             Gastric function tests
# 124         453       3                           Digestive function tests
# 125         454       3                     Chem. metabolic function tests
# 126         45Z       3                         Chemical function test NOS
# 127          46       2                                  Urine examination
# 128         461       3  Urine examination - general (& [MSU] or [urina...
# 129         462       3                                   Urine inspection
# 130         463       3                   Urine specific gravity (& level)
# 131         464       3                                        Urine smell
# 132         465       3                               Urine pregnancy test
# 133         466       3                     Sugar - urine test (& glucose)
# 134         467       3                                 Urine protein test
# 135         468       3                                  Urine ketone test
# 136         46A       3                                      Urine pH test
# 137         46B       3                             Urine bacteriuria test
# 138         46C       3                    Urine dipstick for urobilinogen
# 139         46D       3                         Urine microscopy - general
# 140         46E       3                           Urine microscopy - casts
# 141         46F       3                         Urine microscopy: crystals
# 142         46G       3                            Urine microscopy: cells
# 143         46H       3  Urine microscopy: organisms &/or FB's (& [bact...
# 144         46I       3                     24 hour urine volume (& level)
# 145         46J       3                            Urine sex hormone level
# 146         46K       3                    Urine sex hormone 24 hour assay
# 147         46L       3    Urine non-sex hormone levels (& catecholamines)
# 148         46M       3                       Urine electrolytes (& level)
# 149         46N       3                            Urine protein (& level)
# 150         46O       3                      Urine protein electrophoresis
# 151         46P       3                       Urine trace metals (& level)
# 152         46Q       3                                  Urine drug levels
# 153         46R       3                             Urine - bile chemistry
# 154         46S       3  (Urine reducing subst) or ([sugars][reducing s...
# 155         46T       3                                   Urine levels NOS
# 156         46U       3                                      Urine culture
# 157         46V       3                                 Other urine volume
# 158         46W       3                       Urine microalbumin (& level)
# 159         46X       3                                      Urine nitrite
# 160         46Z       3                                     Urine test NOS
# 161          47       2                              Examination of faeces
# 162         471       3                       Faeces examination - general
# 163         472       3                         Faeces examination - odour
# 164         473       3                        Faeces examination - colour
# 165         474       3                         Faeces exam. - consistency
# 166         475       3                      Faeces examination - quantity
# 167         476       3                      Faeces: abnormal constituents
# 168         477       3    Faeces: foreign constituents (& [organism O/E])
# 169         478       3  Faeces: [pancreat effects] or [fat] or [lipase...
# 170         479       3                           Faecal occult blood test
# 171         47A       3                                          Faeces pH
# 172         47B       3             Presence of faecal reducing substances
# 173         47C       3                        Faeces sugar chromatography
# 174         47D       3                     Faeces examination - organisms
# 175         47Z       3                             Faeces examination NOS
# 176          48       2                    Cerebrospinal fluid examination
# 177         481       3                          CSF examination - general
# 178         482       3                                     CSF appearance
# 179         483       3                       Cerebrospinal fluid pressure
# 180         484       3                   Cerebrospinal fluid cell content
# 181         485       3                                CSF: microorganisms
# 182         486       3                     CSF: chemical content -general
# 183         487       3                            CSF: protein &/or level
# 184         488       3                            CSF: glucose &/or level
# 185         489       3                                CSF: chloride level
# 186         48A       3                           CSF: globulin &/or level
# 187         48B       3                               CSF: electrophoresis
# 188         48Z       3                                CSF examination NOS
# 189          49       2                                     Semen analysis
# 190         491       3                        Semen examination - general
# 191         492       3                                       Semen volume
# 192         493       3  (Sperm number/cc) or (semen examination - number)
# 193         494       3                        Sperm motility at 6-8 hours
# 194         495       3                         Percentage of normal sperm
# 195         496       3                       Sperm: abnormal constituents
# 196         497       3                                 Semen pH (& level)
# 197         498       3                                  Total sperm count
# 198         499       3             Total count of normal and motile sperm
# 199         49A       3                        Total count of motile sperm
# 200         49B       3                                     Sperm motility
# 201         49C       3  Density of morphologically normal and motile s...
# 202         49D       3                            Density of motile sperm
# 203         49E       3                            Tray agglutination test
# 204         49F       3                                   Semen sample age
# 205         49Z       3                              Semen examination NOS
# 206          4A       2                                  Vomit examination
# 207         4A1       3                        Vomit examination - general
# 208         4A2       3                                   Vomit appearance
# 209         4A3       3                                        Vomit odour
# 210         4A4       3                                           Vomit pH
# 211         4A5       3                                 Vomit occult blood
# 212         4A6       3                                   Vomit toxicology
# 213         4AZ       3                              Vomit examination NOS
# 214          4B       2                         Synovial fluid examination
# 215         4B1       3                     Synovial fluid exam. - general
# 216         4B2       3               Synovial fluid: [source] or [sample]
# 217         4B3       3                          Synovial fluid appearance
# 218         4B4       3                           Synovial fluid viscosity
# 219         4B5       3                         Synovial fluid fibrin clot
# 220         4B6       3                          Synovial fluid cell count
# 221         4B7       3                     Synovial fluid abnorm. content
# 222         4BZ       3                           Synovial fluid exam. NOS
# 223          4C       2                            Bone marrow examination
# 224         4C1       3                        Bone marrow exam. - general
# 225         4C2       3                                 Bone marrow source
# 226         4C3       3                 Bone marrow erythropoiesis (& O/E)
# 227         4C4       3                  Bone marrow myeloid cells (& O/E)
# 228         4C5       3                 Bone marrow: foreign cells (& O/E)
# 229         4C6       3                 Bone marrow megakaryocytes (& O/E)
# 230         4CZ       3                              Bone marrow exam. NOS
# 231          4D       2                          Pleural fluid examination
# 232         4D1       3                       Pleural fluid exam.- general
# 233         4D2       3                           Pleural fluid appearance
# 234         4D3       3                     Pleural fluid specific gravity
# 235         4D4       3                      Pleural fluid protein content
# 236         4D5       3                           Pleural fluid microscopy
# 237         4D6       3                                 Pleural fluid type
# 238         4DZ       3                            Pleural fluid exam. NOS
# 239          4E       2  (Examination: [sputum][phlegm][spit]) or (O/E ...
# 240         4E1       3                       Sputum examination - general
# 241         4E2       3                                  Sputum inspection
# 242         4E3       3                                  Sputum microscopy
# 243         4EZ       3                             Sputum examination NOS
# 244          4F       2                          Ascitic fluid examination
# 245         4F1       3                      Ascitic fluid exam. - general
# 246         4F2       3                           Ascitic fluid appearance
# 247         4F3       3                           Ascitic fluid microscopy
# 248         4F4       3                            Ascitic fluid chemistry
# 249         4FZ       3                            Ascitic fluid exam. NOS
# 250          4G       2                               Calculus examination
# 251         4G1       3                             Calculus exam. general
# 252         4G2       3                                     O/E: gallstone
# 253         4G3       3                            O/E: prostatic calculus
# 254         4G4       3                                O/E: renal calculus
# 255         4G5       3                            O/E - salivary calculus
# 256         4G6       3                            O/E - ureteric calculus
# 257         4G7       3                            O/E - urethral calculus
# 258         4G8       3                             O/E - bladder calculus
# 259         4G9       3                                     Stone analysis
# 260         4GA       3                      Calculus chemical composition
# 261         4GZ       3                           Calculus examination NOS
# 262          4H       2                         Amniotic fluid examination
# 263         4H1       3                     Amniotic fluid exam. - general
# 264         4H2       3                          Amniotic fluid appearance
# 265         4H3       3                          Amniotic fluid microscopy
# 266         4H4       3                           Amniotic fluid chemistry
# 267         4H5       3                                 Amniotic fluid AFP
# 268         4H6       3                       Amnicator test - nitrazamine
# 269         4H7       3                          Amniotic fetal cell study
# 270         4HZ       3                           Amniotic fluid exam. NOS
# 271          4I       2                              Miscellaneous samples
# 272         4I1       3                       Sample examination - general
# 273         4I2       3                       Type of sample (& pathology)
# 274         4I3       3                              Fluid sample analysis
# 275         4I4       3                                         Sweat test
# 276         4IZ       3                                  Misc. samples NOS
# 277          4J       2  Microbiology (& [culture - general][sensitivit...
# 278         4J1       3                      Sample - microbiological exam
# 279         4J2       3  Bacteriology: [general (& sample)]/[culture]/[...
# 280         4J3       3               Virology sample: [general] or [sent]
# 281         4J4       3                         Sample: mycology - general
# 282         4J5       3                     Sample: parasitology - general
# 283         4J6       3                     O/E: macroscopically: organism
# 284         4J7       3                      Sample: direct micr. organism
# 285         4J8       3                       O/E: stained micr.: organism
# 286         4J9       3                     O/E: dark ground micr:organism
# 287         4JA       3                          O/E: E.M. micr.: organism
# 288         4JB       3                       Animal inoculation: organism
# 289         4JC       3                           P.M. isolation: organism
# 290         4JD       3  Serology: organism (& [bacteria][fungus][paras...
# 291         4JE       3                     Eye swab taken (& conjunctiva)
# 292         4JF       3                     E.N.T. swab: [taken] or [sent]
# 293         4JG       3                  Skin sample for organism (& swab)
# 294         4JH       3                            GIT sample for organism
# 295         4JI       3            Blood sample for organism (& [culture])
# 296         4JJ       3  Urine sample: [early morn][midstream][for orga...
# 297         4JK       3   GUT sample taken for organism (& [vaginal swab])
# 298         4JL       3                  Miscellaneous sample for organism
# 299         4JN       3                            Helicobacter blood test
# 300         4JO       3                   CLO test for helicobacter pylori
# 301         4JZ       3                                   Microbiology NOS
# 302          4K       2                                  General pathology
# 303         4K1       3                                          Histology
# 304         4K2       3  Cervical smear result (& [dyskaryosis] or [dys...
# 305         4K3       3               Cervical smear - inflammatory change
# 306         4K4       3                     Cervical smear - action needed
# 307         4K5       3                                 Cytology - general
# 308         4K6       3                        Cell chromosome examination
# 309         4K7       3                               Forensic examination
# 310         4K8       3                                    Gross pathology
# 311         4K9       3                             Postmortem examination
# 312         4KA       3                         Vaginal vault smear result
# 313         4KB       3                                  HLA tissue typing
# 314         4KC       3                                    Sputum cytology
# 315         4KZ       3                              General pathology NOS
# 316          4Z       2                           Laboratory procedure NOS

# %% [markdown]
# ## Rank level 2 codes by frequency of appearance in 2020

# %%
highlevelcode='4'
subset = codes.loc[codes["first_digit"].str[0]== highlevelcode]

codelist = tuple(subset.first_digit)

# select events for selcted subset of codelist
sql = f'''select LEFT(CTV3Code,2) AS first_digit, COUNT(Patient_ID) as events
FROM CodedEvent 
WHERE 
ConsultationDate IS NOT NULL 
AND CAST(LEFT(CTV3Code,2) AS VARCHAR) IN {codelist}
AND YEAR(ConsultationDate) = 2020
GROUP BY LEFT(CTV3Code,2)
'''
with closing_connection(dbconn) as connection:
    df = pd.read_sql(sql, connection).sort_values(by="events", ascending=False)
top_l2 = df.merge(subset, on="first_digit", how="left")

top_l2 = top_l2.loc[top_l2["events"]>100000]
top_l2["events (millions)"] = round(top_l2["events"]/1000000, 2)
top_l2 = top_l2.drop("events", axis=1)
top_l2.head(30)
# Out:
# Empty DataFrame
# Columns: [first_digit, digits, Description, events (millions)]
# Index: []

# %% [markdown]
# ## Rank level 3 codes by frequency of appearance in 2020

# %%
codelist = tuple(codes_l3.first_digit)

# select events for selcted subset of codelist
sql = f'''select TOP 50 
LEFT(CTV3Code,3) AS first_digit, COUNT(Patient_ID) as events
FROM CodedEvent 
WHERE 
ConsultationDate IS NOT NULL 
AND CAST(LEFT(CTV3Code,3) AS VARCHAR) IN {codelist}
AND YEAR(ConsultationDate) = 2020
GROUP BY LEFT(CTV3Code,3)
ORDER BY events DESC
'''

with closing_connection(dbconn) as connection:
    df = pd.read_sql(sql, connection).sort_values(by="events", ascending=False)
top_l3 = df.merge(codes_l3, on="first_digit", how="left")

top_l3 = top_l3.loc[top_l3["events"]>10000]
top_l3["events (millions)"] = round(top_l3["events"]/1000000, 2)
top_l3 = top_l3.drop("events", axis=1)
top_l3.head(30)
# Out:
# Empty DataFrame
# Columns: [first_digit, digits, Description, events (millions)]
# Index: []
