# %% [markdown]
# # Changes occurring in primary care ADMINISTRATION activity during the pandemic
#
# ## Producing decile charts to show activity across all practices in TPP

# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown

# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import plotting_all, closing_connection

# %%
server = 'covid.ebmdatalab.net,1433'
database = 'OPENCoronaExport' 
username = 'SA'
password = 'ahsjdkaJAMSHDA123[' 
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

# %%
# real data
server = '192.168.201.1'
database = 'OpenCorona' 
username = 'REDACTED'
password = 'REDACTED'
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

# %%
# global variables 
if server == '192.168.201.1':
    threshold = 1000 # min activity threshold
else:
    threshold = 1

credentials = {
    "server":server, 
    "database":database, 
    "username":username, 
    "password":password}

concept = "Administration"

# %%
Markdown(f"# Load data from csv and filter to {concept} only")
# Out:
# # Load data from csv and filter to Administration only

# %%
codes = pd.read_csv(os.path.join('..','data','code_dictionary.csv'))

top_l2 = pd.read_csv(os.path.join("..","output","level_two_codes.csv"))
top_l2 = top_l2.loc[top_l2["concept_desc"]==concept]

combined = pd.read_csv(os.path.join("..","output","combined_codelist.csv"))
combined = combined.loc[combined["concept_desc"]==concept]

display(len(top_l2))
display(len(combined))
# Out:
# 1
# 43

# %% [markdown]
# # Plotting charts
# ### NB Practice denominators (list size) and patient registrations only include current patients
# ### will need to be amended to per-month denominators

# %% [markdown]
# # Top 150 full / L3 codes

# %%
plotting_all(combined, codes, 43, threshold, credentials, True)
# Out:
# # ---
#  # Category: Administration
# ## Contents:
#     first_digits                                        Description  \
# 0          Y237d  Additional SCR dataset uploaded under COPI Reg...
# 1          XaMiI  Short message service text message sent to pat...
# 3          XaIge                             Telephone consultation
# 9          Y22b6  Provision of advice, assessment or treatment l...
# 10           9N3                                 Indirect encounter
# 17           915                          Patient registration data
# 31           9N1                                  Site of encounter
# 38         XaIvd                         Telephone triage encounter
# 49         XaMJa  Choice and booking enhanced services administr...
# 50           9N4                                   Failed encounter
# 51         XaLQR                             Informed consent given
# 52         XaKqd                                    Letter received
# 54         XaXmW                          Patient identity verified
# 55         Y0428                                                 No
# 58         XE2NQ                           Incoming mail processing
# 63         XaIg4                                Administration note
# 64         Y20d2  SARS-CoV-2 (severe acute respiratory syndrome ...
# 67         XaX1E  eMED3 (2010) new statement issued, not fit for...
# 69         Xa1kG                                     Did not attend
# 76         Y1605                                     Parent present
# 84         Y228a  High risk category for developing complication...
# 93           934                         Computer record of patient
# 97         XaBX8                     Patient contact administration
# 98         Y1f3b               eConsultation via online application
# 102        Y0028                                     Overview Notes
# 111        XacWQ  Patient allocated named accountable general pr...
# 112        XaIgc                        Telephone call to a patient
# 113            9                                     Administration
# 114        Xaafq                            NHS 111 report received
# 115        Xab9D  Informing patient of named accountable general...
# 116        Y4615                       Batch number and expiry date
# 126        Y00e7                      Advice given - cervical smear
# 129        XaN5W  Unsuccessful attempt to contact patient by tel...
# 134        XaKvU                  Referral to practice phlebotomist
# 138        XaQyE                         Internal practice referral
# 139        Y001d                                   Consent obtained
# 140        XaIkK                           Third party consultation
# 141        XaIgb                      Telephone call from a patient
# 142        XaX4c                   Patient accompanied at encounter
# 143        Y212d  Advice given about severe acute respiratory sy...
# 145          8HE                           Discharged from hospital
# 146        Xa1qL                                       Consultation
# 147        Xab2B                   Patient contact details verified
#
#      2020 events (mill)
# 0                 70.94
# 1                 23.31
# 3                  8.27
# 9                  5.78
# 10                 5.53
# 17                 5.25
# 31                 4.31
# 38                 3.71
# 49                 2.71
# 50                 2.66
# 51                 2.60
# 52                 2.56
# 54                 2.45
# 55                 2.40
# 58                 2.25
# 63                 2.08
# 64                 2.06
# 67                 1.86
# 69                 1.81
# 76                 1.56
# 84                 1.23
# 93                 1.07
# 97                 1.03
# 98                 1.03
# 102                0.95
# 111                0.90
# 112                0.90
# 113                0.89
# 114                0.88
# 115                0.84
# 116                0.83
# 126                0.67
# 129                0.65
# 134                0.64
# 138                0.62
# 139                0.62
# 140                0.62
# 141                0.61
# 142                0.61
# 143                0.61
# 145                0.59
# 146                0.59
# 147                0.59
# ## "Y237d" - Additional SCR dataset uploaded under COPI Regulations (2020 events: 70.94m)
# Feb median: 0.2 (IDR 0.9), April median: 1.2 (IDR 91.3), July median: 614.5 (IDR 547.7)
# Change from 2019: April 920.1% (Increase); July 426233.7%, (Increase); Overall classification: **Increase**
# ## "XaMiI" - Short message service text message sent to patient (2020 events: 23.31m)
# Feb median: 12.4 (IDR 356.8), April median: 28.5 (IDR 129.8), July median: 52.9 (IDR 200.0)
# Change from 2019: April 103.9% (Increase); July 289.0%, (Increase); Overall classification: **Increase**
# ## "XaIge" - Telephone consultation (2020 events: 8.27m)
# Feb median: 3.0 (IDR 40.6), April median: 21.9 (IDR 127.4), July median: 31.3 (IDR 157.0)
# Change from 2019: April 1320.6% (Increase); July 1561.5%, (Increase); Overall classification: **Increase**
# ## "Y22b6" - Provision of advice, assessment or treatment limited due to coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 pandemic (situation) (2020 events: 5.78m)
# Feb median: 0.1 (IDR 0.2), April median: 10.4 (IDR 130.6), July median: 27.2 (IDR 163.9)
# Change from 2019: April 7890.3% (Increase); July 20758.7%, (Increase); Overall classification: **Increase**
# ## "9N3" - Indirect encounter (2020 events: 5.53m)
# Feb median: 7.9 (IDR 47.7), April median: 15.0 (IDR 86.9), July median: 15.2 (IDR 107.3)
# Change from 2019: April 124.4% (Increase); July 99.6%, (Increase); Overall classification: **Increase**
# Top codes represented in chart above:
#   first_digits  2020 events (thou)                  Description
# 0         9N31              5331.7          Telephone encounter
# 1         9N32                97.6        Third party encounter
# 2         9N35                70.8  Letter encounter to patient
# 3         9N34                18.3   Encounter by computer link
# 4          9N3                 9.7           Indirect encounter
# ### Trend in top sub-code: 9N31 - Telephone encounter
# ## "915" - Patient registration data (2020 events: 5.25m)
# Feb median: 0.4 (IDR 11.4), April median: 15.4 (IDR 56.4), July median: 33.0 (IDR 110.9)
# Change from 2019: April 7014.6% (Increase); July 14330.3%, (Increase); Overall classification: **Increase**
# Top codes represented in chart above:
#   first_digits  2020 events (thou)                Description
# 5         9159              5146.3   Patient telephone number
# 6          915                33.0  Patient registration data
# 7         9155                29.0              Date of birth
# 8         9153                18.2            Patient address
# 9         915A                11.4         Patient occupation
# ### Trend in top sub-code: 9159 - Patient telephone number
# ## "9N1" - Site of encounter (2020 events: 4.31m)
# Feb median: 23.0 (IDR 72.5), April median: 11.0 (IDR 34.9), July median: 18.9 (IDR 53.8)
# Change from 2019: April -51.7% (Small drop); July -25.3%, (Small drop); Overall classification: **Sustained drop**
# Top codes represented in chart above:
#    first_digits  2020 events (thou)                                Description
# 10         9N19              2031.0  Seen in accident and emergency department
# 11         9N1K               278.4               Seen in ophthalmology clinic
# 12         9N1p               268.1                 Seen in orthopaedic clinic
# 13         9N1I               137.6                     Seen in urology clinic
# 14         9N1L               131.6                         Seen in ENT clinic
# ### Trend in top sub-code: 9N19 - Seen in accident and emergency department
# ## "XaIvd" - Telephone triage encounter (2020 events: 3.71m)
# Feb median: 0.6 (IDR 30.9), April median: 4.6 (IDR 63.0), July median: 7.8 (IDR 83.1)
# Change from 2019: April 605.8% (Increase); July 1063.9%, (Increase); Overall classification: **Increase**
# ## "XaMJa" - Choice and booking enhanced services administration (2020 events: 2.71m)
# Feb median: 20.0 (IDR 17.2), April median: 4.2 (IDR 6.6), July median: 16.3 (IDR 16.0)
# Change from 2019: April -77.5% (Large drop); July -9.6%, (No change); Overall classification: **Recovered**
# ## "9N4" - Failed encounter (2020 events: 2.66m)
# Feb median: 4.7 (IDR 22.5), April median: 9.0 (IDR 25.7), July median: 13.4 (IDR 35.7)
# Change from 2019: April 115.6% (Increase); July 175.3%, (Increase); Overall classification: **Increase**
# Top codes represented in chart above:
#    first_digits  2020 events (thou)  \
# 15         9N4F              1174.3
# 16          9N4               869.8
# 17         9N4C               332.7
# 18         9N4G               100.7
# 19         9N4Z                49.1
#
#                                           Description
# 15  Failed encounter - message left on answer machine
# 16                                   Failed encounter
# 17        Failed encounter - no answer when rang back
# 18       Failed encounter - phone number unobtainable
# 19                               Failed encounter NOS
# ### Trend in top sub-code: 9N4F - Failed encounter - message left on answer machine
# ## "XaLQR" - Informed consent given (2020 events: 2.6m)
# Feb median: 5.8 (IDR 65.9), April median: 4.5 (IDR 24.6), July median: 8.5 (IDR 59.9)
# Change from 2019: April 137.4% (Increase); July 175.1%, (Increase); Overall classification: **Increase**
# ## "XaKqd" - Letter received (2020 events: 2.56m)
# Feb median: 0.5 (IDR 46.1), April median: 0.4 (IDR 49.4), July median: 0.4 (IDR 101.3)
# Change from 2019: April -38.4% (Small drop); July -44.5%, (Small drop); Overall classification: **Sustained drop**
# ## "XaXmW" - Patient identity verified (2020 events: 2.45m)
# Feb median: 0.7 (IDR 16.4), April median: 2.4 (IDR 54.6), July median: 7.2 (IDR 78.4)
# Change from 2019: April 509.3% (Increase); July 1330.7%, (Increase); Overall classification: **Increase**
# ## "Y0428" - No (2020 events: 2.4m)
# Feb median: 5.5 (IDR 15.4), April median: 5.8 (IDR 35.5), July median: 6.6 (IDR 37.2)
# Change from 2019: April 109.6% (Increase); July 67.4%, (Increase); Overall classification: **Increase**
# ## "XE2NQ" - Incoming mail processing (2020 events: 2.25m)
# Feb median: 0.4 (IDR 86.6), April median: 0.4 (IDR 86.2), July median: 0.4 (IDR 146.5)
# Change from 2019: April -19.0% (Small drop); July -24.0%, (Small drop); Overall classification: **Sustained drop**
# ## "XaIg4" - Administration note (2020 events: 2.08m)
# Feb median: 0.8 (IDR 29.9), April median: 0.9 (IDR 28.2), July median: 1.6 (IDR 46.1)
# Change from 2019: April 41.9% (Increase); July 129.3%, (Increase); Overall classification: **Increase**
# ## "Y20d2" - SARS-CoV-2 (severe acute respiratory syndrome coronavirus 2) RNA (ribonucleic acid) detection result negative (2020 events: 2.06m)
# Feb median: 0.2 (IDR 0.5), April median: 1.3 (IDR 2.1), July median: 18.7 (IDR 20.1)
# Change from 2019: April nan% (Other); July nan%, (Other); Overall classification: **Other**
# ## "XaX1E" - eMED3 (2010) new statement issued, not fit for work (2020 events: 1.86m)
# Feb median: 11.8 (IDR 12.4), April median: 7.9 (IDR 9.8), July median: 8.4 (IDR 9.8)
# Change from 2019: April -27.8% (Small drop); July -31.1%, (Small drop); Overall classification: **Sustained drop**
# ## "Xa1kG" - Did not attend (2020 events: 1.81m)
# Feb median: 15.7 (IDR 20.3), April median: 2.9 (IDR 6.5), July median: 5.8 (IDR 10.0)
# Change from 2019: April -80.2% (Large drop); July -65.8%, (Large drop); Overall classification: **Sustained drop**
# ## "Y1605" - Parent present (2020 events: 1.56m)
# Feb median: 8.9 (IDR 14.0), April median: 7.9 (IDR 12.3), July median: 8.0 (IDR 12.5)
# Change from 2019: April -8.2% (No change); July -17.9%, (Small drop); Overall classification: **No change**
# ## "Y228a" - High risk category for developing complication from coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 infection (finding) (2020 events: 1.23m)
# Feb median: 0.1 (IDR 0.2), April median: 21.2 (IDR 34.0), July median: 0.3 (IDR 0.6)
# Change from 2019: April 5432.7% (Increase); July nan%, (Other); Overall classification: **Increase**
# ## "934" - Computer record of patient (2020 events: 1.07m)
# Feb median: 4.3 (IDR 10.6), April median: 5.5 (IDR 15.9), July median: 4.0 (IDR 9.8)
# Change from 2019: April 21.7% (Increase); July -15.1%, (Small drop); Overall classification: **Increase**
# Top codes represented in chart above:
#    first_digits  2020 events (thou)                   Description
# 20         9344               999.9     Notes summary on computer
# 21         9343                33.2  Repeat prescription-computer
# 22         9346                29.5       Total notes on computer
# 23         9345                 4.0   Extensive notes on computer
# 24          934                 2.3    Computer record of patient
# ### Trend in top sub-code: 9344 - Notes summary on computer
# ## "XaBX8" - Patient contact administration (2020 events: 1.03m)
# Feb median: 0.5 (IDR 21.5), April median: 0.6 (IDR 17.8), July median: 0.6 (IDR 60.5)
# Change from 2019: April 69.3% (Increase); July 48.7%, (Increase); Overall classification: **Increase**
# ## "Y1f3b" - eConsultation via online application (2020 events: 1.03m)
# Feb median: 0.3 (IDR 12.2), April median: 0.6 (IDR 19.5), July median: 2.2 (IDR 41.8)
# Change from 2019: April 175.5% (Increase); July 1270.1%, (Increase); Overall classification: **Increase**
# ## "Y0028" - Overview Notes (2020 events: 0.95m)
# Feb median: 2.7 (IDR 15.4), April median: 2.1 (IDR 13.4), July median: 3.2 (IDR 19.0)
# Change from 2019: April 62.9% (Increase); July 88.1%, (Increase); Overall classification: **Increase**
# ## "XacWQ" - Patient allocated named accountable general practitioner (2020 events: 0.9m)
# Feb median: 4.4 (IDR 10.5), April median: 2.2 (IDR 5.4), July median: 4.0 (IDR 8.7)
# Change from 2019: April -51.3% (Small drop); July -17.5%, (Small drop); Overall classification: **Sustained drop**
# ## "XaIgc" - Telephone call to a patient (2020 events: 0.9m)
# Feb median: 0.9 (IDR 8.2), April median: 1.7 (IDR 18.0), July median: 1.9 (IDR 21.0)
# Change from 2019: April 138.0% (Increase); July 161.4%, (Increase); Overall classification: **Increase**
# ## "9" - Administration (2020 events: 0.89m)
# Feb median: 86.7 (IDR 162.3), April median: 90.9 (IDR 161.6), July median: 134.7 (IDR 231.3)
# Change from 2019: April 11.7% (No change); July 47.7%, (Increase); Overall classification: **Increase**
# ## "Xaafq" - NHS 111 report received (2020 events: 0.88m)
# Feb median: 1.2 (IDR 16.6), April median: 2.4 (IDR 16.2), July median: 3.3 (IDR 19.3)
# Change from 2019: April 239.7% (Increase); July 291.9%, (Increase); Overall classification: **Increase**
# ## "Xab9D" - Informing patient of named accountable general practitioner (2020 events: 0.84m)
# Feb median: 3.9 (IDR 10.2), April median: 1.9 (IDR 5.5), July median: 3.6 (IDR 8.8)
# Change from 2019: April -48.8% (Small drop); July -14.5%, (No change); Overall classification: **Recovered**
# ## "Y4615" - Batch number and expiry date (2020 events: 0.83m)
# Feb median: 4.4 (IDR 10.7), April median: 2.6 (IDR 6.5), July median: 4.3 (IDR 10.0)
# Change from 2019: April -12.7% (No change); July 16.0%, (Increase); Overall classification: **Increase**
# ## "Y00e7" - Advice given - cervical smear (2020 events: 0.67m)
# Feb median: 7.7 (IDR 17.9), April median: 1.1 (IDR 4.4), July median: 6.8 (IDR 13.9)
# Change from 2019: April -26.1% (Small drop); July 145.8%, (Increase); Overall classification: **Increase**
# ## "XaN5W" - Unsuccessful attempt to contact patient by telephone (2020 events: 0.65m)
# Feb median: 0.9 (IDR 9.4), April median: 1.7 (IDR 12.0), July median: 2.6 (IDR 15.0)
# Change from 2019: April 163.3% (Increase); July 237.7%, (Increase); Overall classification: **Increase**
# ## "XaKvU" - Referral to practice phlebotomist (2020 events: 0.64m)
# Feb median: 0.5 (IDR 39.6), April median: 1.5 (IDR 13.9), July median: 3.4 (IDR 39.6)
# Change from 2019: April 486.2% (Increase); July 1040.4%, (Increase); Overall classification: **Increase**
# ## "XaQyE" - Internal practice referral (2020 events: 0.62m)
# Feb median: 0.4 (IDR 110.0), April median: 1.0 (IDR 99.1), July median: 1.3 (IDR 151.6)
# Change from 2019: April 308.4% (Increase); July 521.7%, (Increase); Overall classification: **Increase**
# ## "Y001d" - Consent obtained (2020 events: 0.62m)
# Feb median: 1.0 (IDR 30.1), April median: 0.5 (IDR 7.0), July median: 0.6 (IDR 27.6)
# Change from 2019: April -37.3% (Small drop); July -24.3%, (Small drop); Overall classification: **Sustained drop**
# ## "XaIkK" - Third party consultation (2020 events: 0.62m)
# Feb median: 0.8 (IDR 10.1), April median: 2.0 (IDR 16.3), July median: 2.8 (IDR 18.6)
# Change from 2019: April 486.9% (Increase); July 531.0%, (Increase); Overall classification: **Increase**
# ## "XaIgb" - Telephone call from a patient (2020 events: 0.61m)
# Feb median: 0.3 (IDR 3.4), April median: 0.3 (IDR 3.5), July median: 0.3 (IDR 5.8)
# Change from 2019: April 18.0% (Increase); July 13.3%, (No change); Overall classification: **Increase**
# ## "XaX4c" - Patient accompanied at encounter (2020 events: 0.61m)
# Feb median: 5.2 (IDR 18.7), April median: 3.3 (IDR 6.2), July median: 4.3 (IDR 8.3)
# Change from 2019: April 272.4% (Increase); July 150.6%, (Increase); Overall classification: **Increase**
# ## "Y212d" - Advice given about severe acute respiratory syndrome coronavirus 2 infection (situation) (2020 events: 0.61m)
# Feb median: 0.2 (IDR 0.7), April median: 1.5 (IDR 15.0), July median: 0.5 (IDR 18.8)
# Change from 2019: April nan% (Other); July 923.2%, (Increase); Overall classification: **Increase**
# ## "8HE" - Discharged from hospital (2020 events: 0.59m)
# Feb median: 0.9 (IDR 14.1), April median: 0.9 (IDR 7.3), July median: 1.2 (IDR 12.9)
# Change from 2019: April 3.3% (No change); July 31.7%, (Increase); Overall classification: **Increase**
# Top codes represented in chart above:
#    first_digits  2020 events (thou)                     Description
# 25          8HE               476.8        Discharged from hospital
# 26         8HE2                52.5  Discharged from inpatient care
# 27         8HE1                29.6     Discharged from outpatients
# 28         8HE3                15.8   Discharged from day-case care
# 29         8HE5                10.0       Removed from waiting list
# ## "Xa1qL" - Consultation (2020 events: 0.59m)
# Feb median: 0.3 (IDR 4.0), April median: 0.7 (IDR 5.5), July median: 2.1 (IDR 16.0)
# Change from 2019: April 285.2% (Increase); July 861.5%, (Increase); Overall classification: **Increase**
# ## "Xab2B" - Patient contact details verified (2020 events: 0.59m)
# Feb median: 0.4 (IDR 17.3), April median: 0.4 (IDR 8.5), July median: 1.3 (IDR 25.7)
# Change from 2019: April 62.4% (Increase); July 403.3%, (Increase); Overall classification: **Increase**
