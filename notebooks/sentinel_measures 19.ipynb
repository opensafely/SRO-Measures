# %% [markdown]
# <h1 align="center">Changes in sentinel measures of primary care activity during the pandemic</h1>
#
# The purpose of this notebook is to provide measures of overall activity at the practice level during the pandemic.
#
# The following sentinel measures are provided:
# * [2469: O/E - Systolic BP reading](#systolic_bp)
# * [QRISK2 cardiovascular disease 10 risk score](#qrisk2)
# * [Serum Cholesterol level](#cholesterol)
# * [Serum Bilirubin level](#bilirubin)
# * [Serum TSH level](#serum_tsh)
# * [Red blood cell count](#rbc_fbc)
# * [Haemoglobin A1c level - IFCC standardised](#hba1c)
# * [Serum Sodium level](#serum_sodium)
# * [Asthma annual review](#asthma)
# * [Chronic obstrutive pulmonary disease annual review](#copd)

# %%
from IPython.display import HTML
import pandas as pd
import matplotlib.pyplot as plt
from utilities import *

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
sentinel_measures = ["systolic_bp", "qrisk2", "serum_cholesterol", "serum_bilirubin", "serum_tsh", "rbc", "hba1c", "serum_sodium", "asthma", "copd"]

data_dict = {}

for measure in sentinel_measures:
    df = load_and_drop(measure)
    data_dict[measure] = df
    
data_dict_practice = {}

for measure in sentinel_measures:
    df = load_and_drop(measure, practice=True)
    data_dict_practice[measure] = df

sentinel_measure_codelist_mapping_dict = {"systolic_bp":"opensafely-chronic-respiratory-disease", "qrisk2":"opensafely-chronic-respiratory-disease", "serum_cholesterol": "opensafely-chronic-respiratory-disease", "serum_bilirubin": "opensafely-chronic-respiratory-disease", "serum_tsh": "opensafely-chronic-respiratory-disease", "rbc": "opensafely-chronic-respiratory-disease", "hba1c": "opensafely-chronic-respiratory-disease", "serum_sodium": "opensafely-chronic-respiratory-disease", "asthma": "opensafely-chronic-respiratory-disease", "copd": "opensafely-chronic-respiratory-disease"}

codelist_dict = {}
for measure in sentinel_measures:
    codelist_name = sentinel_measure_codelist_mapping_dict[measure]
    codelist = pd.read_csv(f'../codelists/{codelist_name}.csv')
    codelist_dict[measure] = codelist

# %% [markdown]
# <a id="systolic_bp"></a>
# ### O/E - Systolic BP
#
# Description:

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'systolic_bp', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7317.00M (0.01M events)
# Feb Median: 500.0 (IDR: 304.2), April Median: 500.0 (IDR: 666.7), Dec Median: 506.0 (IDR: 505.5)
# Change in median from Feb 2020: April: 0.00%; December: 1.20%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>266.0</td>
#       <td>0.266</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>274.0</td>
#       <td>0.274</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>819.0</td>
#       <td>0.819</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="qrisk"></a>
# ### QRISK2 Cardiovascular Disease 10 year risk score

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'qrisk2', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7313.00M (0.01M events)
# Feb Median: 500.0 (IDR: 315.6), April Median: 500.0 (IDR: 977.3), Dec Median: 466.7 (IDR: 442.9)
# Change in median from Feb 2020: April: 0.00%; December: -6.67%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>239.0</td>
#       <td>0.239</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>241.0</td>
#       <td>0.241</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>797.0</td>
#       <td>0.797</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="cholesterol"></a>
# ### Serum Cholesterol Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_cholesterol', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7350.00M (0.01M events)
# Feb Median: 500.0 (IDR: 322.6), April Median: 454.5 (IDR: 729.8), Dec Median: 500.0 (IDR: 403.6)
# Change in median from Feb 2020: April: -9.09%; December: 0.00%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>272.0</td>
#       <td>0.272</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>284.0</td>
#       <td>0.284</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>761.0</td>
#       <td>0.761</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="bilirubin"></a>
# ### Serum Bilirubin Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_bilirubin', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7315.00M (0.01M events)
# Feb Median: 510.0 (IDR: 580.7), April Median: 449.5 (IDR: 696.7), Dec Median: 500.0 (IDR: 347.5)
# Change in median from Feb 2020: April: -11.86%; December: -1.96%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>248.0</td>
#       <td>0.248</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>818.0</td>
#       <td>0.818</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="serum_tsh"></a>
# ### Serum TSH Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_tsh', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7333.00M (0.01M events)
# Feb Median: 500.0 (IDR: 451.4), April Median: 500.0 (IDR: 966.7), Dec Median: 500.0 (IDR: 484.8)
# Change in median from Feb 2020: April: 0.00%; December: 0.00%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>247.0</td>
#       <td>0.247</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>285.0</td>
#       <td>0.285</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>777.0</td>
#       <td>0.777</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="rbc_fbc"></a>
# ### Red Blood Cell Count

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'rbc', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 36 (124.14%)
# 2020 patients: 7277.00M (0.01M events)
# Feb Median: 500.0 (IDR: 244.8), April Median: 526.5 (IDR: 748.3), Dec Median: 458.3 (IDR: 444.0)
# Change in median from Feb 2020: April: 5.30%; December: -8.33%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>244.0</td>
#       <td>0.244</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>249.0</td>
#       <td>0.249</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>776.0</td>
#       <td>0.776</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="hba1c"></a>
# ### Haemoglobin A1c Level - IFCC Standardised

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'hba1c', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7384.00M (0.01M events)
# Feb Median: 484.4 (IDR: 729.5), April Median: 539.4 (IDR: 966.7), Dec Median: 500.0 (IDR: 444.8)
# Change in median from Feb 2020: April: 11.36%; December: 3.23%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>256.0</td>
#       <td>0.256</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>277.0</td>
#       <td>0.277</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>771.0</td>
#       <td>0.771</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="serum_sodium"></a>
# ### Serum Sodium Level

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'serum_sodium', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 37 (127.59%)
# 2020 patients: 7310.00M (0.01M events)
# Feb Median: 500.0 (IDR: 505.0), April Median: 500.0 (IDR: 784.9), Dec Median: 533.3 (IDR: 327.4)
# Change in median from Feb 2020: April: 0.00%; December: 6.67%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>232.0</td>
#       <td>0.232</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>272.0</td>
#       <td>0.272</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>762.0</td>
#       <td>0.762</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="asthma"></a>
# ### Asthma Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'asthma', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 7300.00M (0.01M events)
# Feb Median: 500.0 (IDR: 397.7), April Median: 496.0 (IDR: 944.2), Dec Median: 508.8 (IDR: 297.1)
# Change in median from Feb 2020: April: -0.80%; December: 1.75%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>248.0</td>
#       <td>0.248</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>250.0</td>
#       <td>0.250</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>788.0</td>
#       <td>0.788</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="copd"></a>
# ### Chronic Obstructive Pulmonary Disease Annual Review

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'copd', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 7351.00M (0.01M events)
# Feb Median: 500.0 (IDR: 414.3), April Median: 500.0 (IDR: 950.5), Dec Median: 502.0 (IDR: 467.9)
# Change in median from Feb 2020: April: 0.00%; December: 0.40%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>257.0</td>
#       <td>0.257</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>802.0</td>
#       <td>0.802</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.read_csv(f'../output/measure_copd_practice_only.csv')

# %%
charts.add_percentiles(
        df,
        period_column='date',
        column='value',
        show_outer_percentiles=False,
    )
# Out:
#            date  percentile     value
# 0    2019-01-01          10  0.357333
# 1    2019-01-01          20  0.435714
# 2    2019-01-01          30  0.465775
# 3    2019-01-01          40  0.491956
# 4    2019-01-01          50  0.500000
# ..          ...         ...       ...
# 229  2021-02-01          50  0.500000
# 230  2021-02-01          60  0.500000
# 231  2021-02-01          70  0.508000
# 232  2021-02-01          80  0.571429
# 233  2021-02-01          90  0.666667
#
# [234 rows x 3 columns]

# %%
df[df['date'] == "2020-04-01"]
# Out:
#      practice   copd  population     value        date
# 443         0  244.0         500  0.488000  2020-04-01
# 444        11    2.0           3  0.666667  2020-04-01
# 445        12    1.0           1  1.000000  2020-04-01
# 446        13    1.0           1  1.000000  2020-04-01
# 447        14    1.0           3  0.333333  2020-04-01
# 448        15    6.0          11  0.545455  2020-04-01
# 449        16    8.0          11  0.727273  2020-04-01
# 450        17    4.0          10  0.400000  2020-04-01
# 451        18    7.0          12  0.583333  2020-04-01
# 452        19    9.0          15  0.600000  2020-04-01
# 453        20   10.0          23  0.434783  2020-04-01
# 454        21   11.0          28  0.392857  2020-04-01
# 455        22   18.0          30  0.600000  2020-04-01
# 456        23   17.0          32  0.531250  2020-04-01
# 457        24   18.0          36  0.500000  2020-04-01
# 458        25   21.0          46  0.456522  2020-04-01
# 459        26   34.0          57  0.596491  2020-04-01
# 460        27   16.0          34  0.470588  2020-04-01
# 461        28   10.0          22  0.454545  2020-04-01
# 462        29   17.0          35  0.485714  2020-04-01
# 463        30   12.0          21  0.571429  2020-04-01
# 464        31   13.0          19  0.684211  2020-04-01
# 465        32    4.0          18  0.222222  2020-04-01
# 466        33    9.0          14  0.642857  2020-04-01
# 467        34    3.0           9  0.333333  2020-04-01
# 468        35    2.0           2  1.000000  2020-04-01
# 469        36    0.0           1  0.000000  2020-04-01
# 470        37    1.0           1  1.000000  2020-04-01
# 471        38    1.0           2  0.500000  2020-04-01
# 472        39    0.0           1  0.000000  2020-04-01
# 473        40    0.0           1  0.000000  2020-04-01
# 474        41    0.0           1  0.000000  2020-04-01

# %%
def generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, measure, code_colum, term_column, dates_list):
    df = data_dict[measure]
    childs_df = create_child_table(df, codelist_dict[measure], 'CTV3ID', 'CTV3PreferredTermDesc', measure)

    practices_included, practices_included_percent, num_events_mil, num_patients = calculate_statistics(
        df, measure, dates_list)


    df = data_dict_practice[measure]
    convert_datetime(df)
    calculate_rate(df, measure, 'population')
 
    
    
    idr_list = [get_idr(df, dates_list)[x]
                for x in dates_list]


    median_list = [get_median(df, dates_list)[x]
               for x in dates_list]
    
    

    change_list = calculate_change_median(median_list)

    print(f'Practices included: {practices_included} ({practices_included_percent}%)')
    print(f'2020 patients: {num_patients:.2f}M ({num_events_mil:.2f}M events)')
    print(
        f'Feb Median: {median_list[0]:.1f} (IDR: {idr_list[0]:.1f}), April Median: {median_list[1]:.1f} (IDR: {idr_list[1]:.1f}), Dec Median: {median_list[2]:.1f} (IDR: {idr_list[2]:.1f})')
    print(
        f'Change in median from Feb 2020: April: {change_list[0]:.2f}%; December: {change_list[1]:.2f}%')
    
    display(HTML(childs_df.to_html()))

    charts.deciles_chart(
        data_dict_practice[measure],
        period_column="date",
        column="num_per_thousand",
        title=measure,
        ylabel="rate per 1000",
        show_legend=True,
    )

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'copd', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 7351.00M (0.01M events)
# Feb Median: 500.0 (IDR: 414.3), April Median: 500.0 (IDR: 950.5), Dec Median: 502.0 (IDR: 467.9)
# Change in median from Feb 2020: April: 0.00%; December: 0.40%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>257.0</td>
#       <td>0.257</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>802.0</td>
#       <td>0.802</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>

# %%
def interactive_deciles_chart(
    df,
    period_column=None,
    column=None,
    title="",
    ylabel=""
):
    """period_column must be dates / datetimes
    """
 
    df = charts.add_percentiles(
        df,
        period_column=period_column,
        column=column,
        show_outer_percentiles=False,
    )
    
    fig = go.Figure()

    linestyles = {
        "decile": {"color": "blue", "dash": "dash"},
        "median": {"color": "blue", "dash": "solid"},
        "percentile": {"color": "blue", "dash": "dash"},
    }
    
 
    for percentile in np.unique(df['percentile']):
        df_subset = df[df['percentile'] == percentile]
        if percentile == 50:
            fig.add_trace(go.Scatter(x=df_subset[period_column], y=df_subset[column], line={"color": "blue", "dash": "solid", "width": 1.2}, name="median"))
        else:
            fig.add_trace(go.Scatter(x=df_subset[period_column], y=df_subset[column], line={"color": "blue", "dash": "dash", "width": 1}, name=f"decile {int(percentile/10)}"))
      
         
    
     # Set title
    fig.update_layout(
        title_text=title,
        hovermode='x',
        title_x=0.5,


    )

    fig.update_yaxes(title=ylabel)
    fig.update_xaxes(title="Date")

    # Add range slider
    fig.update_layout(
        xaxis=go.layout.XAxis(
            rangeselector=dict(
                buttons=list([
                    dict(count=1,
                         label="1m",
                         step="month",
                         stepmode="backward"),
                    dict(count=6,
                         label="6m",
                         step="month",
                         stepmode="backward"),

                    dict(count=1,
                         label="1y",
                         step="year",
                         stepmode="backward"),
                    dict(step="all")
                ])
            ),
            rangeslider=dict(
                visible=True
            ),
            type="date"
        )
    )
    
    fig.show()

# %%
def generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, measure, code_colum, term_column, dates_list):
    df = data_dict[measure]
    childs_df = create_child_table(df, codelist_dict[measure], 'CTV3ID', 'CTV3PreferredTermDesc', measure)

    practices_included, practices_included_percent, num_events_mil, num_patients = calculate_statistics(
        df, measure, dates_list)


    df = data_dict_practice[measure]
    convert_datetime(df)
    calculate_rate(df, measure, 'population')
    
    idr_list = [get_idr(df, dates_list)[x]
                for x in dates_list]


    median_list = [get_median(df, dates_list)[x]
               for x in dates_list]

    change_list = calculate_change_median(median_list)

    print(f'Practices included: {practices_included} ({practices_included_percent}%)')
    print(f'2020 patients: {num_patients:.2f}M ({num_events_mil:.2f}M events)')
    print(
        f'Feb Median: {median_list[0]:.1f} (IDR: {idr_list[0]:.1f}), April Median: {median_list[1]:.1f} (IDR: {idr_list[1]:.1f}), Dec Median: {median_list[2]:.1f} (IDR: {idr_list[2]:.1f})')
    print(
        f'Change in median from Feb 2020: April: {change_list[0]:.2f}%; December: {change_list[1]:.2f}%')
    
    display(HTML(childs_df.to_html()))

    interactive_deciles_chart(
        data_dict_practice[measure],
        period_column="date",
        column="num_per_thousand",
        title=measure,
        ylabel="rate per 1000"
    )

# %%
generate_sentinel_measure(data_dict, data_dict_practice, codelist_dict, 'copd', 'CTV3ID', 'CTV3PreferredTermDesc', ["2020-02-01", "2020-04-01", "2020-12-01"])
# Out:
# Practices included: 38 (131.03%)
# 2020 patients: 7351.00M (0.01M events)
# Feb Median: 500.0 (IDR: 414.3), April Median: 500.0 (IDR: 950.5), Dec Median: 502.0 (IDR: 467.9)
# Change in median from Feb 2020: April: 0.00%; December: 0.40%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CTV3ID</th>
#       <th>Events</th>
#       <th>Events (thousands)</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7450.</th>
#       <td>7450.</td>
#       <td>257.0</td>
#       <td>0.257</td>
#       <td>Lung transplant</td>
#     </tr>
#     <tr>
#       <th>663K.</th>
#       <td>663K.</td>
#       <td>259.0</td>
#       <td>0.259</td>
#       <td>Airways obstructn irreversible</td>
#     </tr>
#     <tr>
#       <th>23E5.</th>
#       <td>23E5.</td>
#       <td>802.0</td>
#       <td>0.802</td>
#       <td>O/E - fibrosis of lung present</td>
#     </tr>
#   </tbody>
# </table>
# <div>                            <div id="536701d6-3fb3-4984-9808-476ae76d300c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("536701d6-3fb3-4984-9808-476ae76d300c")) {                    Plotly.newPlot(                        "536701d6-3fb3-4984-9808-476ae76d300c",                        [{"line": {"color": "blue", "dash": "dash", "width": 1}, "name": "decile 1", "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-08-01T00:00:00", "2020-09-01T00:00:00", "2020-10-01T00:00:00", "2020-11-01T00:00:00", "2020-12-01T00:00:00", "2021-01-01T00:00:00", "2021-02-01T00:00:00"], "y": [357.3333333333333, 402.5974025974026, 125.0, 393.73040752351096, 362.5, 400.0, 200.00000000000006, 381.0344827586207, 200.00000000000006, 326.6666666666667, 297.72727272727275, 277.14285714285717, 142.85714285714286, 300.0000000000001, 0.0, 22.222222222222243, 0.0, 354.76190476190476, 241.0, 0.0, 381.7204301075269, 331.7073170731707, 236.5079365079365, 382.1138211382114, 225.00000000000009, 0.0]}, {"line": {"color": "blue", "dash": "dash", "width": 1}, "name": "decile 2", "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-08-01T00:00:00", "2020-09-01T00:00:00", "2020-10-01T00:00:00", "2020-11-01T00:00:00", "2020-12-01T00:00:00", "2021-01-01T00:00:00", "2021-02-01T00:00:00"], "y": [435.7142857142857, 465.1515151515152, 375.0, 442.9411764705882, 416.0, 461.53846153846155, 333.3333333333333, 448.3370288248337, 407.05882352941177, 404.44444444444446, 343.58974358974365, 342.5287356321839, 333.3333333333333, 389.76744186046517, 309.2592592592593, 345.2380952380953, 294.11764705882354, 391.9191919191919, 375.8620689655172, 400.0, 409.4117647058824, 388.5714285714286, 376.92307692307696, 421.45748987854256, 366.6666666666667, 400.0]}, {"line": {"color": "blue", "dash": "dash", "width": 1}, "name": "decile 3", "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-02-01T00:00:00", "2019-03-01T00:00:00", "2019-04-01T00:00:00", "2019-05-01T00:00:00", "2019-06-01T00:00:00", "2019-07-01T00:00:00", "2019-08-01T00:00:00", "2019-09-01T00:00:00", "2019-10-01T00:00:00", "2019-11-01T00:00:00", "2019-12-01T00:00:00", "2020-01-01T00:00:00", "2020-02-01T00:00:00", "2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-08-01T00:00:00", "2020-09-01T00:00:00", "2020-10-01T00:00:00", "2020-11-01T00:00:00", "2020-12-01T00:00:00", "2021-01-01T00:00:00", "2021-02-01T00:00:00"], "y": [465.7754010695187, 500.0, 406.25, 483.8787878787879, 481.0794044665013, 478.26086956521743, 440.27777777777777, 472.0888888888889, 476.5090909090909, 463.1272727272728, 394.70588235294116, 442.36111111111114, 454.54545454545456, 437.87375415282395, 333.3333333333333, 440.71146245059293, 391.30434782608694, 444.44444444444446, 391.42857142857144, 441.17647058823525, 425.80645161290323, 458.0769230769231, 452.66457680250784, 428.57142857142856, 457.98319327731093, 457.1428571428571]}, {"line ...
